# %%
from dotenv import load_dotenv
import os

load_dotenv()
qdarnt_api_key = os.getenv("QDRANT_API_KEY")

# %%
from qdrant_client import QdrantClient

qdrant_client = QdrantClient(
    url="https://7c78ac85-306b-4026-9bce-130101367b02.us-east4-0.gcp.cloud.qdrant.io:6333", 
    api_key=qdarnt_api_key,
)

print(qdrant_client.get_collections())
# Out:
# collections=[CollectionDescription(name='love_counseling_db')]
